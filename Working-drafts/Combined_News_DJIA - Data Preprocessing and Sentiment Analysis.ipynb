# %% [markdown]
# # Combined_News_DJIA - Data Preprocessing and Sentiment Analysis

# %% [markdown]
# Link to Kaggle dataset:
# https://www.kaggle.com/aaron7sun/stocknews
#
# Useful links:
# https://www.analyticsvidhya.com/blog/2018/02/the-different-methods-deal-text-data-predictive-python/

# %% [markdown]
# ## Import packages

# %%
import nltk

#If you are running this for the first time, uncomment and download the VADER list of words / lexicon
# nltk.download('vader_lexicon')

# %%
import pandas as pd
import numpy as np

from nltk.stem import PorterStemmer
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import MultinomialNB

# %% [markdown]
# ## Load data sets

# %%
DJIA_news = pd.read_csv("Combined_News_DJIA.csv")
DJIA = pd.read_csv("DJIA_table.csv")
reddit = pd.read_csv("RedditNews.csv")

# %% [markdown]
# # Data pre-processing

# %% [markdown]
# ### Data Inspection

# %%
DJIA_news.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1989 entries, 0 to 1988
# Data columns (total 27 columns):
# Date     1989 non-null object
# Label    1989 non-null int64
# Top1     1989 non-null object
# Top2     1989 non-null object
# Top3     1989 non-null object
# Top4     1989 non-null object
# Top5     1989 non-null object
# Top6     1989 non-null object
# Top7     1989 non-null object
# Top8     1989 non-null object
# Top9     1989 non-null object
# Top10    1989 non-null object
# Top11    1989 non-null object
# Top12    1989 non-null object
# Top13    1989 non-null object
# Top14    1989 non-null object
# Top15    1989 non-null object
# Top16    1989 non-null object
# Top17    1989 non-null object
# Top18    1989 non-null object
# Top19    1989 non-null object
# Top20    1989 non-null object
# Top21    1989 non-null object
# Top22    1989 non-null object
# Top23    1988 non-null object
# Top24    1986 non-null object
# Top25    1986 non-null object
# dtypes: int64(1), object(26)
# memory usage: 419.6+ KB

# %% [markdown]
# #### Observations:
#
# 1. Date column is object type
#
# 2. Not all days have 25 news headlines (Top23, Top24, Top25)

# %%
#Changing Date column's type to Datetime
DJIA_news.Date = pd.to_datetime(DJIA_news.Date)

DJIA_news.dtypes
# Out:
# Date     datetime64[ns]
# Label             int64
# Top1             object
# Top2             object
# Top3             object
# Top4             object
# Top5             object
# Top6             object
# Top7             object
# Top8             object
# Top9             object
# Top10            object
# Top11            object
# Top12            object
# Top13            object
# Top14            object
# Top15            object
# Top16            object
# Top17            object
# Top18            object
# Top19            object
# Top20            object
# Top21            object
# Top22            object
# Top23            object
# Top24            object
# Top25            object
# dtype: object

# %%
DJIA_news.head()
# Out:
#         Date  Label                                               Top1  \
# 0 2008-08-08      0  b"Georgia 'downs two Russian warplanes' as cou...
# 1 2008-08-11      1  b'Why wont America and Nato help us? If they w...
# 2 2008-08-12      0  b'Remember that adorable 9-year-old who sang a...
# 3 2008-08-13      0  b' U.S. refuses Israel weapons to attack Iran:...
# 4 2008-08-14      1  b'All the experts admit that we should legalis...
#
#                                                 Top2  \
# 0            b'BREAKING: Musharraf to be impeached.'
# 1        b'Bush puts foot down on Georgian conflict'
# 2                 b"Russia 'ends Georgia operation'"
# 3  b"When the president ordered to attack Tskhinv...
# 4  b'War in South Osetia - 89 pictures made by a ...
#
#                                                 Top3  \
# 0  b'Russia Today: Columns of troops roll into So...
# 1  b"Jewish Georgian minister: Thanks to Israeli ...
# 2  b'"If we had no sexual harassment we would hav...
# 3  b' Israel clears troops who killed Reuters cam...
# 4  b'Swedish wrestler Ara Abrahamian throws away ...
#
#                                                 Top4  \
# 0  b'Russian tanks are moving towards the capital...
# 1  b'Georgian army flees in disarray as Russians ...
# 2  b"Al-Qa'eda is losing support in Iraq because ...
# 3  b'Britain\'s policy of being tough on drugs is...
# 4  b'Russia exaggerated the death toll in South O...
#
#                                                 Top5  \
# 0  b"Afghan children raped with 'impunity,' U.N. ...
# 1      b"Olympic opening ceremony fireworks 'faked'"
# 2  b'Ceasefire in Georgia: Putin Outmaneuvers the...
# 3  b'Body of 14 year old found in trunk; Latest (...
# 4  b'Missile That Killed 9 Inside Pakistan May Ha...
#
#                                                 Top6  \
# 0  b'150 Russian tanks have entered South Ossetia...
# 1  b'What were the Mossad with fraudulent New Zea...
# 2  b'Why Microsoft and Intel tried to kill the XO...
# 3  b'China has moved 10 *million* quake survivors...
# 4  b"Rushdie Condemns Random House's Refusal to P...
#
#                                                 Top7  \
# 0  b"Breaking: Georgia invades South Ossetia, Rus...
# 1  b'Russia angered by Israeli military sale to G...
# 2  b'Stratfor: The Russo-Georgian War and the Bal...
# 3  b"Bush announces Operation Get All Up In Russi...
# 4  b'Poland and US agree to missle defense deal. ...
#
#                                                 Top8  ...  \
# 0  b"The 'enemy combatent' trials are nothing but...  ...
# 1  b'An American citizen living in S.Ossetia blam...  ...
# 2  b"I'm Trying to Get a Sense of This Whole Geor...  ...
# 3             b'Russian forces sink Georgian ships '  ...
# 4  b'Will the Russians conquer Tblisi? Bet on it,...  ...
#
#                                                Top16  \
# 0  b'Georgia Invades South Ossetia - if Russia ge...
# 1  b'Israel and the US behind the Georgian aggres...
# 2  b'U.S. troops still in Georgia (did you know t...
# 3                      b'Elephants extinct by 2020?'
# 4  b'Bank analyst forecast Georgian crisis 2 days...
#
#                                                Top17  \
# 0                b'Al-Qaeda Faces Islamist Backlash'
# 1  b'"Do not believe TV, neither Russian nor Geor...
# 2       b'Why Russias response to Georgia was right'
# 3  b'US humanitarian missions soon in Georgia - i...
# 4  b"Georgia confict could set back Russia's US r...
#
#                                                Top18  \
# 0  b'Condoleezza Rice: "The US would not act to p...
# 1  b'Riots are still going on in Montreal (Canada...
# 2  b'Gorbachev accuses U.S. of making a "serious ...
# 3             b"Georgia's DDOS came from US sources"
# 4  b'War in the Caucasus is as much the product o...
#
#                                                Top19  \
# 0  b'This is a busy day:  The European Union has ...
# 1    b'China to overtake US as largest manufacturer'
# 2         b'Russia, Georgia, and NATO: Cold War Two'
# 3  b'Russian convoy heads into Georgia, violating...
# 4  b'"Non-media" photos of South Ossetia/Georgia ...
#
#                                                Top20  \
# 0  b"Georgia will withdraw 1,000 soldiers from Ir...
# 1                     b'War in South Ossetia [PICS]'
# 2  b'Remember that adorable 62-year-old who led y...
# 3  b'Israeli defence minister: US against strike ...
# 4  b'Georgian TV reporter shot by Russian sniper ...
#
#                                                Top21  \
# 0  b'Why the Pentagon Thinks Attacking Iran is a ...
# 1  b'Israeli Physicians Group Condemns State Tort...
# 2          b'War in Georgia: The Israeli connection'
# 3                     b'Gorbachev: We Had No Choice'
# 4  b'Saudi Arabia: Mother moves to block child ma...
#
#                                                Top22  \
# 0  b'Caucasus in crisis: Georgia invades South Os...
# 1  b' Russia has just beaten the United States ov...
# 2  b'All signs point to the US encouraging Georgi...
# 3  b'Witness: Russian forces head towards Tbilisi...
# 4   b'Taliban wages war on humanitarian aid workers'
#
#                                                Top23  \
# 0  b'Indian shoe manufactory  - And again in a se...
# 1  b'Perhaps *the* question about the Georgia - R...
# 2  b'Christopher King argues that the US and NATO...
# 3  b' Quarter of Russians blame U.S. for conflict...
# 4  b'Russia: World  "can forget about" Georgia\'s...
#
#                                                Top24  \
# 0  b'Visitors Suffering from Mental Illnesses Ban...
# 1                 b'Russia is so much better at war'
# 2                        b'America: The New Mexico?'
# 3  b'Georgian president  says US military will ta...
# 4  b'Darfur rebels accuse Sudan of mounting major...
#
#                                                Top25
# 0           b"No Help for Mexico's Kidnapping Surge"
# 1  b"So this is what it's come to: trading sex fo...
# 2  b"BBC NEWS | Asia-Pacific | Extinction 'by man...
# 3  b'2006: Nobel laureate Aleksander Solzhenitsyn...
# 4  b'Philippines : Peace Advocate say Muslims nee...
#
# [5 rows x 27 columns]

# %% [markdown]
# ### Text Cleaning
#
# 1. Removing first letter 'b'
# 2. Convert headlines to lower case
# 3. Removing punctuation
#
# As we will be using the VADER sentiment analysis later on, which takes punctuation into account, we will only implement point 1 to our original dataset.
#
# For points 2 and 3, we will implement it in a separate copy of the dataset which will be used to calculate relevance.

# %%
DJIA_news_col = DJIA_news.columns

for i in range(2, len(DJIA_news_col)):
    DJIA_news[DJIA_news_col[i]] = DJIA_news[DJIA_news_col[i]].astype(str)
    DJIA_news[DJIA_news_col[i]] = DJIA_news[DJIA_news_col[i]].apply(lambda x: x[1:] if x[0] == "b" else x)

# %%
DJIA_news.head()
# Out:
#         Date  Label                                               Top1  \
# 0 2008-08-08      0  "Georgia 'downs two Russian warplanes' as coun...
# 1 2008-08-11      1  'Why wont America and Nato help us? If they wo...
# 2 2008-08-12      0  'Remember that adorable 9-year-old who sang at...
# 3 2008-08-13      0  ' U.S. refuses Israel weapons to attack Iran: ...
# 4 2008-08-14      1  'All the experts admit that we should legalise...
#
#                                                 Top2  \
# 0             'BREAKING: Musharraf to be impeached.'
# 1         'Bush puts foot down on Georgian conflict'
# 2                  "Russia 'ends Georgia operation'"
# 3  "When the president ordered to attack Tskhinva...
# 4  'War in South Osetia - 89 pictures made by a R...
#
#                                                 Top3  \
# 0  'Russia Today: Columns of troops roll into Sou...
# 1  "Jewish Georgian minister: Thanks to Israeli t...
# 2  '"If we had no sexual harassment we would have...
# 3  ' Israel clears troops who killed Reuters came...
# 4  'Swedish wrestler Ara Abrahamian throws away m...
#
#                                                 Top4  \
# 0  'Russian tanks are moving towards the capital ...
# 1  'Georgian army flees in disarray as Russians a...
# 2  "Al-Qa'eda is losing support in Iraq because o...
# 3  'Britain\'s policy of being tough on drugs is ...
# 4  'Russia exaggerated the death toll in South Os...
#
#                                                 Top5  \
# 0  "Afghan children raped with 'impunity,' U.N. o...
# 1       "Olympic opening ceremony fireworks 'faked'"
# 2  'Ceasefire in Georgia: Putin Outmaneuvers the ...
# 3  'Body of 14 year old found in trunk; Latest (r...
# 4  'Missile That Killed 9 Inside Pakistan May Hav...
#
#                                                 Top6  \
# 0  '150 Russian tanks have entered South Ossetia ...
# 1  'What were the Mossad with fraudulent New Zeal...
# 2  'Why Microsoft and Intel tried to kill the XO ...
# 3  'China has moved 10 *million* quake survivors ...
# 4  "Rushdie Condemns Random House's Refusal to Pu...
#
#                                                 Top7  \
# 0  "Breaking: Georgia invades South Ossetia, Russ...
# 1  'Russia angered by Israeli military sale to Ge...
# 2  'Stratfor: The Russo-Georgian War and the Bala...
# 3  "Bush announces Operation Get All Up In Russia...
# 4  'Poland and US agree to missle defense deal. I...
#
#                                                 Top8  ...  \
# 0  "The 'enemy combatent' trials are nothing but ...  ...
# 1  'An American citizen living in S.Ossetia blame...  ...
# 2  "I'm Trying to Get a Sense of This Whole Georg...  ...
# 3              'Russian forces sink Georgian ships '  ...
# 4  'Will the Russians conquer Tblisi? Bet on it, ...  ...
#
#                                                Top16  \
# 0  'Georgia Invades South Ossetia - if Russia get...
# 1  'Israel and the US behind the Georgian aggress...
# 2  'U.S. troops still in Georgia (did you know th...
# 3                       'Elephants extinct by 2020?'
# 4  'Bank analyst forecast Georgian crisis 2 days ...
#
#                                                Top17  \
# 0                 'Al-Qaeda Faces Islamist Backlash'
# 1  '"Do not believe TV, neither Russian nor Georg...
# 2        'Why Russias response to Georgia was right'
# 3  'US humanitarian missions soon in Georgia - if...
# 4  "Georgia confict could set back Russia's US re...
#
#                                                Top18  \
# 0  'Condoleezza Rice: "The US would not act to pr...
# 1  'Riots are still going on in Montreal (Canada)...
# 2  'Gorbachev accuses U.S. of making a "serious b...
# 3              "Georgia's DDOS came from US sources"
# 4  'War in the Caucasus is as much the product of...
#
#                                                Top19  \
# 0  'This is a busy day:  The European Union has a...
# 1     'China to overtake US as largest manufacturer'
# 2          'Russia, Georgia, and NATO: Cold War Two'
# 3  'Russian convoy heads into Georgia, violating ...
# 4  '"Non-media" photos of South Ossetia/Georgia c...
#
#                                                Top20  \
# 0  "Georgia will withdraw 1,000 soldiers from Ira...
# 1                      'War in South Ossetia [PICS]'
# 2  'Remember that adorable 62-year-old who led yo...
# 3  'Israeli defence minister: US against strike o...
# 4  'Georgian TV reporter shot by Russian sniper d...
#
#                                                Top21  \
# 0  'Why the Pentagon Thinks Attacking Iran is a B...
# 1  'Israeli Physicians Group Condemns State Torture'
# 2           'War in Georgia: The Israeli connection'
# 3                      'Gorbachev: We Had No Choice'
# 4  'Saudi Arabia: Mother moves to block child mar...
#
#                                                Top22  \
# 0  'Caucasus in crisis: Georgia invades South Oss...
# 1  ' Russia has just beaten the United States ove...
# 2  'All signs point to the US encouraging Georgia...
# 3  'Witness: Russian forces head towards Tbilisi ...
# 4    'Taliban wages war on humanitarian aid workers'
#
#                                                Top23  \
# 0  'Indian shoe manufactory  - And again in a ser...
# 1  'Perhaps *the* question about the Georgia - Ru...
# 2  'Christopher King argues that the US and NATO ...
# 3  ' Quarter of Russians blame U.S. for conflict:...
# 4  'Russia: World  "can forget about" Georgia\'s ...
#
#                                                Top24  \
# 0  'Visitors Suffering from Mental Illnesses Bann...
# 1                  'Russia is so much better at war'
# 2                         'America: The New Mexico?'
# 3  'Georgian president  says US military will tak...
# 4  'Darfur rebels accuse Sudan of mounting major ...
#
#                                                Top25
# 0            "No Help for Mexico's Kidnapping Surge"
# 1  "So this is what it's come to: trading sex for...
# 2  "BBC NEWS | Asia-Pacific | Extinction 'by man ...
# 3  '2006: Nobel laureate Aleksander Solzhenitsyn ...
# 4  'Philippines : Peace Advocate say Muslims need...
#
# [5 rows x 27 columns]

# %% [markdown]
# #### Stemming
#
# As stemming may affect our sentiment analysis, we will be creating a copy of the dataset before stemming.
#
# The stemmed dataset will be used to calculate relevance between the various headlines.

# %%
DJIA_news2 = DJIA_news.copy()
DJIA_news2_col = DJIA_news2.columns

for i in range(2, len(DJIA_news_col)):
    DJIA_news2[DJIA_news_col[i]] = DJIA_news2[DJIA_news2_col[i]].apply(lambda x: x.lower())
    DJIA_news2[DJIA_news_col[i]] = DJIA_news2[DJIA_news2_col[i]].str.replace('[^\w\s]','')

# %%
st = PorterStemmer()

DJIA_news2_col = DJIA_news2.columns

for i in range(2, len(DJIA_news2_col)):
    DJIA_news2[DJIA_news2_col[i]] = DJIA_news2[DJIA_news2_col[i]].apply(lambda x: " ".join([st.stem(word) for word in x.split()]))

# %%
DJIA_news2.head()
# Out:
#         Date  Label                                               Top1  \
# 0 2008-08-08      0  georgia down two russian warplan as countri mo...
# 1 2008-08-11      1  whi wont america and nato help us if they wont...
# 2 2008-08-12      0  rememb that ador 9yearold who sang at the open...
# 3 2008-08-13      0       us refus israel weapon to attack iran report
# 4 2008-08-14      1   all the expert admit that we should legalis drug
#
#                                                 Top2  \
# 0                      break musharraf to be impeach
# 1            bush put foot down on georgian conflict
# 2                            russia end georgia oper
# 3  when the presid order to attack tskhinvali the...
# 4  war in south osetia 89 pictur made by a russia...
#
#                                                 Top3  \
# 0  russia today column of troop roll into south o...
# 1  jewish georgian minist thank to isra train wer...
# 2  if we had no sexual harass we would have no ch...
# 3       israel clear troop who kill reuter cameraman
# 4  swedish wrestler ara abrahamian throw away med...
#
#                                                 Top4  \
# 0  russian tank are move toward the capit of sout...
# 1  georgian armi flee in disarray as russian adva...
# 2  alqaeda is lose support in iraq becaus of a br...
# 3  britain polici of be tough on drug is pointles...
# 4  russia exagger the death toll in south ossetia...
#
#                                                 Top5  \
# 0  afghan children rape with impun un offici say ...
# 1                  olymp open ceremoni firework fake
# 2       ceasefir in georgia putin outmaneuv the west
# 3  bodi of 14 year old found in trunk latest rans...
# 4  missil that kill 9 insid pakistan may have bee...
#
#                                                 Top6  \
# 0  150 russian tank have enter south ossetia whil...
# 1  what were the mossad with fraudul new zealand ...
# 2  whi microsoft and intel tri to kill the xo 100...
# 3  china ha move 10 million quak survivor into pr...
# 4  rushdi condemn random hous refus to publish no...
#
#                                                 Top7  \
# 0  break georgia invad south ossetia russia warn ...
# 1      russia anger by isra militari sale to georgia
# 2  stratfor the russogeorgian war and the balanc ...
# 3  bush announc oper get all up in russia grill y...
# 4  poland and us agre to missl defens deal intere...
#
#                                                 Top8  ...  \
# 0  the enemi combat trial are noth but a sham sal...  ...
# 1  an american citizen live in sossetia blame us ...  ...
# 2  im tri to get a sens of thi whole georgiarussi...  ...
# 3                    russian forc sink georgian ship  ...
# 4  will the russian conquer tblisi bet on it no s...  ...
#
#                                                Top16  \
# 0  georgia invad south ossetia if russia get invo...
# 1      israel and the us behind the georgian aggress
# 2  us troop still in georgia did you know they we...
# 3                              eleph extinct by 2020
# 4   bank analyst forecast georgian crisi 2 day earli
#
#                                                Top17  \
# 0                     alqaeda face islamist backlash
# 1  do not believ tv neither russian nor georgian ...
# 2             whi russia respons to georgia wa right
# 3  us humanitarian mission soon in georgia if rus...
# 4  georgia confict could set back russia us relat...
#
#                                                Top18  \
# 0  condoleezza rice the us would not act to preve...
# 1  riot are still go on in montreal canada becaus...
# 2  gorbachev accus us of make a seriou blunder in...
# 3                     georgia ddo came from us sourc
# 4  war in the caucasu is as much the product of a...
#
#                                                Top19  \
# 0  thi is a busi day the european union ha approv...
# 1          china to overtak us as largest manufactur
# 2               russia georgia and nato cold war two
# 3      russian convoy head into georgia violat truce
# 4    nonmedia photo of south ossetiageorgia conflict
#
#                                                Top20  \
# 0  georgia will withdraw 1000 soldier from iraq t...
# 1                           war in south ossetia pic
# 2  rememb that ador 62yearold who led your countr...
# 3       isra defenc minist us against strike on iran
# 4  georgian tv report shot by russian sniper dure...
#
#                                                Top21  \
# 0  whi the pentagon think attack iran is a bad id...
# 1          isra physician group condemn state tortur
# 2                    war in georgia the isra connect
# 3                          gorbachev we had no choic
# 4    saudi arabia mother move to block child marriag
#
#                                                Top22  \
# 0       caucasu in crisi georgia invad south ossetia
# 1  russia ha just beaten the unit state over the ...
# 2  all sign point to the us encourag georgia to i...
# 3  wit russian forc head toward tbilisi in breach...
# 4        taliban wage war on humanitarian aid worker
#
#                                                Top23  \
# 0  indian shoe manufactori and again in a seri of...
# 1  perhap the question about the georgia russia c...
# 2  christoph king argu that the us and nato are b...
# 3      quarter of russian blame us for conflict poll
# 4  russia world can forget about georgia territor...
#
#                                                Top24  \
# 0      visitor suffer from mental ill ban from olymp
# 1                    russia is so much better at war
# 2                             america the new mexico
# 3  georgian presid say us militari will take cont...
# 4     darfur rebel accus sudan of mount major attack
#
#                                                Top25
# 0                     no help for mexico kidnap surg
# 1       so thi is what it come to trade sex for food
# 2       bbc news asiapacif extinct by man not climat
# 3  2006 nobel laureat aleksand solzhenitsyn accus...
# 4  philippin peac advoc say muslim need assur chr...
#
# [5 rows x 27 columns]

# %% [markdown]
# # -- End of Data Preprocessing --

# %% [markdown]
# # Calculating Relevance score
#
# We will use the Jaccard Similarity to determine how similar each headline is compared to the rest of the headlines for that particular day.
#
# The higher the score, the more relevant the headline is for that particular day. This means that the events mentioned in the higher scoring headlines are likely to be larger events.
#
# Since stock markets are sensitive to current affairs, larger events are likely to affect the stock market more.
#
# Hence, using the relevance score, we will be able to add weightage to the sentiment score for each headline.

# %%
DJIA_news2_row = DJIA_news2.shape[0]
DJIA_news_jaccard = []

def calculate_jaccard_score(d1, d2):
    set_a, set_b = set(d1), set(d2)
    return len(set_a & set_b) / len(set_a | set_b)

for i in range(DJIA_news2_row):
    jaccard_score_list = []
    for j in range(2, len(DJIA_news2_col)):
        jaccard_scores = []
        for k in range(2, len(DJIA_news2_col)):
            if j != k:
                jaccard_scores.append(calculate_jaccard_score(DJIA_news2.iloc[i][j], DJIA_news2.iloc[i][k]))
        jaccard_score_list.append(np.mean(jaccard_scores))
    DJIA_news_jaccard.append(jaccard_score_list)

# %%
#Converting into Dataframe
DJIA_news_jaccard_df = pd.DataFrame(DJIA_news_jaccard)

#Adding column name
DJIA_news_jaccard_df.columns = (DJIA_news2.columns[2:])

DJIA_news_jaccard_df.head()
# Out:
#        Top1      Top2      Top3      Top4      Top5      Top6      Top7  \
# 0  0.743682  0.637267  0.750373  0.782153  0.769567  0.581044  0.680257
# 1  0.695923  0.717916  0.637781  0.719973  0.520379  0.652183  0.616578
# 2  0.697748  0.542614  0.627454  0.697886  0.693806  0.641040  0.740321
# 3  0.658834  0.676661  0.669712  0.708683  0.589353  0.615724  0.678822
# 4  0.660675  0.676434  0.672871  0.638886  0.609757  0.739593  0.695038
#
#        Top8      Top9     Top10    ...        Top16     Top17     Top18  \
# 0  0.660511  0.750307  0.620418    ...     0.720483  0.529736  0.722943
# 1  0.704732  0.637517  0.602522    ...     0.653665  0.701607  0.682673
# 2  0.718132  0.733290  0.684228    ...     0.729916  0.622667  0.738715
# 3  0.625214  0.679337  0.555979    ...     0.373997  0.630092  0.560927
# 4  0.613225  0.694340  0.654393    ...     0.606681  0.670824  0.729257
#
#       Top19     Top20     Top21     Top22     Top23     Top24     Top25
# 0  0.740832  0.705644  0.752041  0.622460  0.748700  0.631304  0.676312
# 1  0.669827  0.623605  0.683917  0.622511  0.664112  0.601276  0.576546
# 2  0.650858  0.657616  0.595659  0.717359  0.709430  0.533200  0.580802
# 3  0.631035  0.653917  0.512024  0.712802  0.637300  0.698961  0.576185
# 4  0.756877  0.720952  0.679731  0.653483  0.682259  0.605093  0.717553
#
# [5 rows x 25 columns]

# %% [markdown]
# # Sentiment Analysis
#
# We will split the sentiment analysis into 3 parts.
#
# For part 1, we will calculate a sentiment score for each headline.
#
# For part 2, we will bring in the relevance score and calculate a weighted sentiment score for each headline.
#
# For part 3, we will calculate an overall sentiment score for each day.

# %% [markdown]
# ## Part 1
#
# To calculate the sentiment score, we will use the sentiment analyzer from the `nltk` library. It uses the VADER method or **Valence Aware Dictionary for sEntiment Reasoning**. It is a lexicon (vocabulary) of words and their relative sentiment strength.

# %%
sid = SentimentIntensityAnalyzer()

DJIA_news_row = DJIA_news.shape[0]
DJIA_news_sentiment = []

for i in range(DJIA_news_row):
    sentiment_score_list = []
    for j in range(2, len(DJIA_news_col)):
        ss = sid.polarity_scores(DJIA_news.iloc[i][j])
        sentiment_score = ss['compound']
        sentiment_score_list.append(sentiment_score)
    DJIA_news_sentiment.append(sentiment_score_list)

# %%
#Converting into Dataframe
DJIA_news_sentiment_df = pd.DataFrame(DJIA_news_sentiment)

#Adding column name
DJIA_news_sentiment_df.columns = (DJIA_news.columns[2:])

DJIA_news_sentiment_df.head()
# Out:
#      Top1    Top2    Top3    Top4    Top5    Top6    Top7    Top8    Top9  \
# 0 -0.5994  0.0000 -0.3612 -0.7089 -0.9260  0.0000 -0.2732  0.2144 -0.5719
# 1  0.7964 -0.3182  0.4404 -0.1965  0.0000 -0.4939 -0.5106 -0.0772 -0.2263
# 2  0.0258  0.0000 -0.7845 -0.6124  0.0000 -0.6908 -0.5994 -0.5994  0.3400
# 3 -0.7184 -0.8074 -0.6369 -0.1280 -0.5106  0.0000  0.5106  0.0000  0.3612
# 4  0.2023 -0.5994  0.6808 -0.8689 -0.6124 -0.6369  0.6908 -0.4404 -0.6808
#
#     Top10   ...     Top16   Top17   Top18   Top19   Top20   Top21   Top22  \
# 0 -0.5994   ...   -0.5994  0.0000 -0.3125  0.2023  0.0258 -0.7579 -0.6249
# 1 -0.3400   ...   -0.2960 -0.3804 -0.8271  0.0000 -0.5994 -0.8020  0.0000
# 2 -0.7650   ...    0.0000  0.0000  0.0772 -0.5994 -0.5859 -0.5994  0.5267
# 3  0.4019   ...    0.0000  0.0000  0.0000 -0.5423 -0.0258 -0.2960  0.4939
# 4 -0.3400   ...   -0.6249  0.0000 -0.7579 -0.3182  0.0000 -0.4404 -0.5994
#
#     Top23   Top24   Top25
# 0 -0.2755 -0.8519  0.1280
# 1 -0.3182 -0.1832  0.0000
# 2  0.3818  0.0000  0.0000
# 3 -0.5719 -0.4215 -0.3400
# 4  0.1779 -0.6908  0.7096
#
# [5 rows x 25 columns]

# %% [markdown]
# ## Part 2
#
# To calculate the weighted sentiment score, we will multiply the sentiment score by its relevance score.

# %%
DJIA_news_weighted_df = DJIA_news_jaccard_df * DJIA_news_sentiment_df
DJIA_news_weighted_df.head()
# Out:
#        Top1      Top2      Top3      Top4      Top5      Top6      Top7  \
# 0 -0.445763  0.000000 -0.271035 -0.554468 -0.712619  0.000000 -0.185846
# 1  0.554233 -0.228441  0.280879 -0.141475  0.000000 -0.322113 -0.314825
# 2  0.018002  0.000000 -0.492237 -0.427385  0.000000 -0.442830 -0.443749
# 3 -0.473306 -0.546336 -0.426540 -0.090711 -0.300924  0.000000  0.346607
# 4  0.133654 -0.405455  0.458090 -0.555128 -0.373415 -0.471047  0.480132
#
#        Top8      Top9     Top10    ...        Top16     Top17     Top18  \
# 0  0.141614 -0.429101 -0.371879    ...    -0.431857  0.000000 -0.225920
# 1 -0.054405 -0.144270 -0.204858    ...    -0.193485 -0.266891 -0.564639
# 2 -0.430448  0.249319 -0.523435    ...     0.000000  0.000000  0.057029
# 3  0.000000  0.245376  0.223448    ...     0.000000  0.000000  0.000000
# 4 -0.270064 -0.472707 -0.222494    ...    -0.379115  0.000000 -0.552704
#
#       Top19     Top20     Top21     Top22     Top23     Top24     Top25
# 0  0.149870  0.018206 -0.569972 -0.388975 -0.206267 -0.537808  0.086568
# 1  0.000000 -0.373789 -0.548501  0.000000 -0.211321 -0.110154  0.000000
# 2 -0.390124 -0.385297 -0.357038  0.377833  0.270860  0.000000  0.000000
# 3 -0.342210 -0.016871 -0.151559  0.352053 -0.364472 -0.294612 -0.195903
# 4 -0.240838  0.000000 -0.299354 -0.391698  0.121374 -0.417998  0.509176
#
# [5 rows x 25 columns]

# %% [markdown]
# ## Part 3
#
# To calculate the overall sentiment for a particular day, we will find the average of all the weighted sentiment scores of that day.

# %%
DJIA_news_overall_sentiment = DJIA_news[['Date', 'Label']]


DJIA_news_overall_sentiment['DJIA_news_sentiment'] = DJIA_news_weighted_df.mean(axis=1)

DJIA_news_overall_sentiment.head()
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
#         Date  Label  DJIA_news_sentiment
# 0 2008-08-08      0            -0.256694
# 1 2008-08-11      1            -0.103339
# 2 2008-08-12      0            -0.163408
# 3 2008-08-13      0            -0.091632
# 4 2008-08-14      1            -0.128635
